# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format ='retina'

# %% [markdown]
# Common mental disorders include depression, which affects about 300 million, bipolar disorder, which affects about 60 million, dementia, which affects about 50 million, and schizophrenia and other psychoses, which affects about 23 million people globally
# Content
#
# Key Facts WHO:
# https://www.who.int/mental_health/in_the_workplace/en/
#
#     Work is good for mental health but a negative working environment can lead to physical and mental health problems.
#     Depression and anxiety have a significant economic impact; the estimated cost to the global economy is US$ 1 trillion per year in lost productivity.
#     Harassment and bullying at work are commonly reported problems, and can have a substantial adverse impact on mental health.
#     There are many effective actions that organizations can take to promote mental health in the workplace; such actions may also benefit productivity.
#     For every US$ 1 put into scaled up treatment for common mental disorders, there is a return of US$ 4 in improved health and productivity.
#
#
# This dataset contains the following data:
#
#     Timestamp
#
#     Age
#
#     Gender
#
#     Country
#
#     state: If you live in the United States, which state or territory do you live in?
#
#     self_employed: Are you self-employed?
#
#     family_history: Do you have a family history of mental illness?
#
#     treatment: Have you sought treatment for a mental health condition?
#
#     work_interfere: If you have a mental health condition, do you feel that it interferes with your work?
#
#     no_employees: How many employees does your company or organization have?
#
#     remote_work: Do you work remotely (outside of an office) at least 50% of the time?
#
#     tech_company: Is your employer primarily a tech company/organization?
#
#     benefits: Does your employer provide mental health benefits?
#
#     care_options: Do you know the options for mental health care your employer provides?
#
#     wellness_program: Has your employer ever discussed mental health as part of an employee wellness program?
#
#     seek_help: Does your employer provide resources to learn more about mental health issues and how to seek help?
#
#     anonymity: Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources?
#
#     leave: How easy is it for you to take medical leave for a mental health condition?
#
#     mental_health_consequence: Do you think that discussing a mental health issue with your employer would have negative consequences?
#
#     phys_health_consequence: Do you think that discussing a physical health issue with your employer would have negative consequences?
#
#     coworkers: Would you be willing to discuss a mental health issue with your coworkers?
#
#     supervisor: Would you be willing to discuss a mental health issue with your direct supervisor(s)?
#
#     mental_health_interview: Would you bring up a mental health issue with a potential employer in an interview?
#
#     phys_health_interview: Would you bring up a physical health issue with a potential employer in an interview?
#
#     mental_vs_physical: Do you feel that your employer takes mental health as seriously as physical health?
#
#     obs_consequence: Have you heard of or observed negative consequences for coworkers with mental health conditions in your workplace?
#
#     comments: Any additional notes or comments

# %%
df = pd.read_csv("survey.csv")
df.head(10)
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
# 5  2014-08-27 11:31:22   33    Male   United States    TN           NaN
# 6  2014-08-27 11:31:50   35  Female   United States    MI           NaN
# 7  2014-08-27 11:32:05   39       M          Canada   NaN           NaN
# 8  2014-08-27 11:32:39   42  Female   United States    IL           NaN
# 9  2014-08-27 11:32:43   23    Male          Canada   NaN           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# ...

# %%
df["work_interfere"].fillna("NA", inplace=True)
df
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %% [markdown]
# let's drop the data for people whose employer is not primarily a tech company, as we are focusing on tech people
# lets also drop people over 65 since we are focusing on recruitment needs
# lets drop the column state since it won't affect our analysis, as well as the data for people self-employed since
# we are focusing on a company environement

# %%
df["tech_company"].value_counts()
# Out:
# Yes    1031
# No      228
# Name: tech_company, dtype: int64

# %%
survey =df[df.tech_company != 'No']
survey.shape
# Out:
# (1031, 27)

# %%
survey = survey[survey.Age <= 65]
survey.shape
# Out:
# (1029, 27)

# %%
survey.drop(columns = ["state"], inplace=True)
survey.shape
# Out:
# (1029, 26)

# %%
survey["self_employed"].value_counts() #882 No 131 Yes
survey = survey[survey.self_employed != "Yes"]
survey.shape
# Out:
# (898, 26)

# %% [markdown]
# Lets clean the gender column and we should have a clean dataset to work on to answer our questions

# %%
survey["Gender"].value_counts()
# Out:
# Male                        451
# male                        141
# M                            89
# Female                       87
# female                       39
# F                            28
# m                            20
# f                             9
# Make                          4
# Male                          3
# Female                        2
# Man                           2
# Cis Male                      2
# cis male                      1
# Androgyne                     1
# Mail                          1
# Femake                        1
# non-binary                    1
# queer/she/they                1
# male leaning androgynous      1
# Female (trans)                1
# something kinda male?         1
# Malr                          1
# Agender                       1
# fluid                         1
# Male-ish                      1
# Trans-female                  1
# Enby                          1
# msle                          1
# ...

# %%
# check gender
gender_map = {'male': 'm', 'Male': 'm', 'M': 'm', 'Man':'m','Mail':'m','maile':'m','Cis Male':'m', 'msle':'m', 'female': 'f', 'Female': 'f', 'F': 'f','femake':'f','Woman':'f'}
survey['Gender'] = survey['Gender'].map(gender_map)
survey.head(25)
# Out:
#               Timestamp  Age Gender         Country self_employed  \
# 0   2014-08-27 11:29:31   37      f   United States           NaN
# 2   2014-08-27 11:29:44   32      m          Canada           NaN
# 3   2014-08-27 11:29:46   31      m  United Kingdom           NaN
# 4   2014-08-27 11:30:22   31      m   United States           NaN
# 5   2014-08-27 11:31:22   33      m   United States           NaN
# 6   2014-08-27 11:31:50   35      f   United States           NaN
# 7   2014-08-27 11:32:05   39      m          Canada           NaN
# 8   2014-08-27 11:32:39   42      f   United States           NaN
# 9   2014-08-27 11:32:43   23      m          Canada           NaN
# 10  2014-08-27 11:32:44   31      m   United States           NaN
# 11  2014-08-27 11:32:49   29      m        Bulgaria           NaN
# 13  2014-08-27 11:33:26   36      m   United States           NaN
# 14  2014-08-27 11:33:57   27      m          Canada           NaN
# ...

# %%
#lets drop the rows where the data is not f and m since it is a small proportion of the total of rows
survey = survey[(survey.Gender == "f") | (survey.Gender == "m")]
survey.shape
# Out:
# (843, 26)

# %% [markdown]
# Now let's try to find indicators of mental health condition in this dataframe

# %%
pd.__version__
# Out:
# '0.25.1'

# %%
from pandas_profiling import ProfileReport

# %%
#survey.profile_report()

# %%
# treatment: Have you sought treatment for a mental health condition?
survey["treatment"].value_counts()
# Out:
# No     428
# Yes    415
# Name: treatment, dtype: int64

# %%
c = pd.crosstab(survey.Gender, survey.treatment).apply(lambda r: r/r.sum(), axis=1)
c
#Women seem to seek a lot more treatment regarding mental illnesses (about twice as much)
# Out:
# treatment        No       Yes
# Gender
# f          0.290323  0.709677
# m          0.556686  0.443314

# %%
c.T.plot.bar(stacked=False)
plt.xticks(rotation = 360)
# Out:
# (array([0, 1]), <a list of 2 Text xticklabel objects>)

# %%
d = pd.crosstab(survey.Country, survey.treatment, margins =True).reset_index()
d
# Out:
# treatment                 Country   No  Yes  All
# 0                       Australia    5   10   15
# 1                         Austria    1    0    1
# 2                         Belgium    3    0    3
# 3          Bosnia and Herzegovina    1    0    1
# 4                          Brazil    3    1    4
# 5                        Bulgaria    2    2    4
# 6                          Canada   23   20   43
# 7                        Colombia    2    0    2
# 8                      Costa Rica    1    0    1
# 9                         Croatia    0    1    1
# 10                 Czech Republic    1    0    1
# 11                        Finland    1    1    2
# 12                         France    8    1    9
# 13                        Germany   16   10   26
# 14                         Greece    2    0    2
# 15                          India    4    3    7
# 16                        Ireland    9   11   20
# 17                         Israel    4    0    4
# ...

# %%
#first you can ask people in the interview if they have a MH but most people won't say 
survey["mental_health_interview"].value_counts()
# Out:
# No       671
# Maybe    146
# Yes       26
# Name: mental_health_interview, dtype: int64

# %%
d = pd.crosstab(survey.Country, survey.treatment, margins =True).reset_index()
#, normalize="index"
d
#It seems people from Wester Europe and Canada are less likely to have sought mental illness treatment
Western_E=["Austria","Belgium","France","Germany","Greece","Ireland","Italy","Netherlands","Portugal","Spain","Switzerland","United Kingdom"]
Eastern_E=["Bosnia and Herzegovina","Bulgaria","Croatia","Czech Republic","Latvia","Moldova","Poland","Russia","Slovenia","Israel"]
Northern_E=["Finland","Sweden"]
Africa=["Nigeria","South Africa"]
Asia=["India","Singapore","Philippines"]
Oceania = ["Australia","New Zealand"]
North_Am=["United States","Mexico","Canada"]
Cent_South_Am=["Brazil","Colombia","Costa Rica","Uruguay"]

Western_E = {x: 'Western Europe' for x in Western_E}
Eastern_E = {x : 'Eastern Europe' for x in Eastern_E}
Northern_E = {x : 'Northern Europe' for x in Northern_E}
Africa= {x : 'Africa' for x in Africa}
Asia = {x : 'Asia' for x in Asia}
Oceania = {x : 'Oceania' for x in Oceania}
North_Am ={ x : "North America" for x in North_Am}
Cent_South_Am={x : "Central and South America" for x in Cent_South_Am}
continents = {**Western_E,**Eastern_E,**Northern_E,**Africa,**Asia,**Oceania,**North_Am,**Cent_South_Am}
print(continents)

d['Country'] = d['Country'].map(continents)
#d['Ratio'] = d.No / d.All
d2 = d.groupby('Country')[["No","Yes","All"]].agg(sum).reset_index()
d2['Ratio'] = d2.Yes / d2.All
#d3 = d2.loc[(d2.All > 50) & (d2.Ratio > 0.5)]
#d3
d2
# Out:
# {'Austria': 'Western Europe', 'Belgium': 'Western Europe', 'France': 'Western Europe', 'Germany': 'Western Europe', 'Greece': 'Western Europe', 'Ireland': 'Western Europe', 'Italy': 'Western Europe', 'Netherlands': 'Western Europe', 'Portugal': 'Western Europe', 'Spain': 'Western Europe', 'Switzerland': 'Western Europe', 'United Kingdom': 'Western Europe', 'Bosnia and Herzegovina': 'Eastern Europe', 'Bulgaria': 'Eastern Europe', 'Croatia': 'Eastern Europe', 'Czech Republic': 'Eastern Europe', 'Latvia': 'Eastern Europe', 'Moldova': 'Eastern Europe', 'Poland': 'Eastern Europe', 'Russia': 'Eastern Europe', 'Slovenia': 'Eastern Europe', 'Israel': 'Eastern Europe', 'Finland': 'Northern Europe', 'Sweden': 'Northern Europe', 'Nigeria': 'Africa', 'South Africa': 'Africa', 'India': 'Asia', 'Singapore': 'Asia', 'Philippines': 'Asia', 'Australia': 'Oceania', 'New Zealand': 'Oceania', 'United States': 'North America', 'Mexico': 'North America', 'Canada': 'North America', 'Brazil': 'Central and S
# ...

# %%
#let's focus on North America and Western_Europe since they are the only 2 with a large enough sample
d4=d2[(d2.Country == "Western Europe")|(d2.Country =="North America")]
d5 = d4.rename({4 : "North America", 7 : "Western Europe"})
d5[["Country","Ratio"]].plot.bar()
plt.xticks(rotation = 360)
# Out:
# (array([0, 1]), <a list of 2 Text xticklabel objects>)

# %%
#check age


survey.loc[(survey['treatment'] == "Yes")]['Age'].mean() #31.97

survey.loc[(survey['treatment'] == "No")]['Age'].mean() #31.15

#The age doesnt seem to be an issue

survey.loc[(survey['treatment'] == "Yes")]['Age'].median() #31

survey.loc[(survey['treatment'] == "No")]['Age'].median() #30.5
# Out:
# 30.5

# %% [markdown]
# If one company is looking for a standard profile that is less likely to have been treated for mental health issues : said company should try to hire a *man* from *Western Europe* or *Canada*, with *no condition of age*.

# %% [markdown]
# However, this doesn't take into account the fact that some people that may not have sought treatment can still suffer from mental illnesses (typically, men seem to suffer in silence when it comes to mental illnesses). This can cause a lack of productivity.
#
# A smarter solution may be to improve the well-being of employees. Let's see if we can identify particular aspects that may improve the work environment.

# %%
"""leave: How easy is it for you to take medical leave for a mental health condition?

mental_health_consequence: Do you think that discussing a mental health issue with your employer would have negative consequences?

phys_health_consequence: Do you think that discussing a physical health issue with your employer would have negative consequences?

coworkers: Would you be willing to discuss a mental health issue with your coworkers?

supervisor: Would you be willing to discuss a mental health issue with your direct supervisor(s)?

mental_vs_physical: Do you feel that your employer takes mental health as seriously as physical health?

obs_consequence: Have you heard of or observed negative consequences for coworkers with mental health conditions in your workplace?"""
# Out:
# 'leave: How easy is it for you to take medical leave for a mental health condition?\n\nmental_health_consequence: Do you think that discussing a mental health issue with your employer would have negative consequences?\n\nphys_health_consequence: Do you think that discussing a physical health issue with your employer would have negative consequences?\n\ncoworkers: Would you be willing to discuss a mental health issue with your coworkers?\n\nsupervisor: Would you be willing to discuss a mental health issue with your direct supervisor(s)?\n\nmental_vs_physical: Do you feel that your employer takes mental health as seriously as physical health?\n\nobs_consequence: Have you heard of or observed negative consequences for coworkers with mental health conditions in your workplace?'

# %%
survey_no = survey[survey.treatment == "No"]
survey_no.leave.value_counts()
# Out:
# Don't know            228
# Somewhat easy          85
# Very easy              69
# Somewhat difficult     26
# Very difficult         20
# Name: leave, dtype: int64

# %%
survey_no.mental_health_consequence.value_counts()
# Out:
# No       202
# Maybe    147
# Yes       79
# Name: mental_health_consequence, dtype: int64

# %%
survey_no.mental_vs_physical.value_counts()
# Out:
# Don't know    223
# Yes           115
# No             90
# Name: mental_vs_physical, dtype: int64

# %%
survey_no.obs_consequence.value_counts()
# Out:
# No     390
# Yes     38
# Name: obs_consequence, dtype: int64

# %%
survey_yes = survey[survey.treatment == "Yes"]

# %%
survey_yes.leave.value_counts()
# Out:
# Don't know            179
# Somewhat easy          83
# Very easy              71
# Somewhat difficult     46
# Very difficult         36
# Name: leave, dtype: int64

# %%
survey_yes.mental_health_consequence.value_counts()
# Out:
# Maybe    168
# No       142
# Yes      105
# Name: mental_health_consequence, dtype: int64

# %%
survey_yes.mental_vs_physical.value_counts()
# Out:
# Don't know    184
# No            124
# Yes           107
# Name: mental_vs_physical, dtype: int64

# %%
survey_yes.obs_consequence.value_counts()
# Out:
# No     352
# Yes     63
# Name: obs_consequence, dtype: int64

# %% [markdown]
# the perception of the company envirnoment regarding mental health issues for people who already sought treatment seems different than for the others, lets get more into details about this, focusing on all the negative markers to see if people with prior treatment have a more negative perception of the company regarding this issue.

# %%
y1=survey_yes.obs_consequence.value_counts(normalize=True)["Yes"]  #focus on yes
y1
# Out:
# 0.15180722891566265

# %%
n1=survey_no.obs_consequence.value_counts(normalize=True)['Yes']
n1
# Out:
# 0.08878504672897196

# %%
y2=survey_yes.leave.value_counts(normalize=True)[["Somewhat difficult","Very difficult"]].sum() #focus on somewhat difficult , difficult
y2
# Out:
# 0.19759036144578312

# %%
n2=survey_no.leave.value_counts(normalize=True)[["Somewhat difficult","Very difficult"]].sum()
n2
# Out:
# 0.10747663551401869

# %%
y3=survey_yes.mental_health_consequence.value_counts(normalize=True)["Yes"] #focus on yes
y3
# Out:
# 0.25301204819277107

# %%
n3=survey_no.mental_health_consequence.value_counts(normalize=True)["Yes"]
n3
# Out:
# 0.18457943925233644

# %%
y4=survey_yes.mental_vs_physical.value_counts(normalize=True)['No'] #focus on no
y4
# Out:
# 0.2987951807228916

# %%
n4=survey_no.mental_vs_physical.value_counts(normalize=True)["No"]
n4
# Out:
# 0.2102803738317757

# %%
#The perception of people who already had treatment is more negative for every variable

# %%
data = {'No prior treatment':  [n1,n2,n3,n4],
        'Prior treatment': [y1,y2,y3,y4],
        }

df = pd.DataFrame (data, columns = ['No prior treatment','Prior treatment'])
df
df1 = df.rename({0:"Observed negative consequences on colleagues", 1 : "Finds it difficult to take leave for MH", 2 :"Fears discussing MH with employer", 3 : "Thinks MH is not taken as  seriously as physical"})

# %%
df1.plot.bar()
plt.xticks(rotation = 63)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text xticklabel objects>)
