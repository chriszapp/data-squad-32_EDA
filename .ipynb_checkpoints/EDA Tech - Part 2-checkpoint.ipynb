# %% [markdown]
# ## 3. Analyse Data - MVP
# For the MVP I'll analyse the sub-groups of people with a mental health condition.
# As the criteria for having a MH condition I'll consider the "treatment" entry, as there isn't any other one especified for this.

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('survey_clean.csv', index_col=0)
data.head()
# Out:
#           Country   Age Gender self_employed family_history treatment  \
# 0   United States  37.0  woman           NaN             No       Yes
# 1   United States  44.0    man           NaN             No        No
# 2          Canada  32.0    man           NaN             No        No
# 3  United Kingdom  31.0    man           NaN            Yes       Yes
# 4   United States  31.0    man           NaN             No        No
#
#   work_interfere    no_employees remote_work tech_company  ...   anonymity  \
# 0          Often            6-25          No          Yes  ...         Yes
# 1         Rarely  More than 1000          No           No  ...  Don't know
# 2         Rarely            6-25          No          Yes  ...  Don't know
# 3          Often          26-100          No          Yes  ...          No
# 4          Never         100-500         Yes          Yes  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %%
data['treatment'].value_counts()
# Out:
# Yes    596
# No     532
# Name: treatment, dtype: int64

# %%
data['treatment'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### 3.1 MH condition by Country
# I'll manipulate the data to get a table with the percentage of 'Yes' and 'No' for the MH Condition (using the treatment), by country and weighted with the number of records per country.

# %%
country_total = data[['Country','treatment']].groupby('Country').count()
country_total.reset_index(inplace=True)
country_total.columns = ['Country', 'Total']
country_total
# Out:
#           Country  Total
# 0       Australia     21
# 1          Canada     72
# 2         Germany     45
# 3         Ireland     27
# 4     Netherlands     27
# 5  United Kingdom    185
# 6   United States    751

# %%
country_yes = data[['Country','treatment']][data['treatment'] == 'Yes'].groupby('Country').count()
country_yes.reset_index(inplace=True)
country_yes.columns = ['Country', 'Condition Yes']
country_yes
# Out:
#           Country  Condition Yes
# 0       Australia             13
# 1          Canada             37
# 2         Germany             21
# 3         Ireland             13
# 4     Netherlands              9
# 5  United Kingdom             93
# 6   United States            410

# %%
country_no = data[['Country','treatment']][data['treatment'] == 'No'].groupby('Country').count()
country_no.reset_index(inplace=True)
country_no.columns = ['Country', 'Condition No']
country_no
# Out:
#           Country  Condition No
# 0       Australia             8
# 1          Canada            35
# 2         Germany            24
# 3         Ireland            14
# 4     Netherlands            18
# 5  United Kingdom            92
# 6   United States           341

# %%
condition_by_country = pd.merge(country_yes, country_no, on='Country')
condition_by_country = pd.merge(condition_by_country, country_total, on='Country')
condition_by_country
# Out:
#           Country  Condition Yes  Condition No  Total
# 0       Australia             13             8     21
# 1          Canada             37            35     72
# 2         Germany             21            24     45
# 3         Ireland             13            14     27
# 4     Netherlands              9            18     27
# 5  United Kingdom             93            92    185
# 6   United States            410           341    751

# %%
condition_by_country['% Yes'] = round(condition_by_country['Condition Yes'] / condition_by_country['Total'] * 100, 1)
condition_by_country['% No'] = round(condition_by_country['Condition No'] / condition_by_country['Total'] * 100, 1)
condition_by_country.sort_values(by=['% Yes'], ascending=False, inplace=True)
condition_by_country
# Out:
#           Country  Condition Yes  Condition No  Total  % Yes  % No
# 0       Australia             13             8     21   61.9  38.1
# 6   United States            410           341    751   54.6  45.4
# 1          Canada             37            35     72   51.4  48.6
# 5  United Kingdom             93            92    185   50.3  49.7
# 3         Ireland             13            14     27   48.1  51.9
# 2         Germany             21            24     45   46.7  53.3
# 4     Netherlands              9            18     27   33.3  66.7

# %%
cy = plt.bar(condition_by_country['Country'], condition_by_country['% Yes'], color='c')
cn = plt.bar(condition_by_country['Country'], condition_by_country['% No'], bottom=condition_by_country['% Yes'], color='lavender')
plt.xticks(rotation=45)
plt.ylabel('% Records')
plt.title('MH Condition by Country')
plt.legend((cy,cn),('Yes','No'))
plt.show()

# %% [markdown]
# Conclusion: from this chart we see the countries with more MH condition (Australia) and less MH condition (Netherlands), we also see that in general about 50% of the people have a MH condition which is a very significant insight.

# %% [markdown]
# #### 3.2 MH condition by Age
# I'll manipulate the data to get a table with the percentage of 'Yes' and 'No' for the MH Condition (using the treatment), by age and weighted with the number of records per age.

# %%
age_total = data[['Age','treatment']].groupby('Age').count()
age_total.reset_index(inplace=True)
age_total.columns = ['Age', 'Total']
age_total = age_total.astype(int)

# %%
age_yes = data[['Age','treatment']][data['treatment'] == 'Yes'].groupby('Age').count()
age_yes.reset_index(inplace=True)
age_yes.columns = ['Age', 'Condition Yes']
age_yes = age_yes.astype(int)

# %%
age_no = data[['Age','treatment']][data['treatment'] == 'No'].groupby('Age').count()
age_no.reset_index(inplace=True)
age_no.columns = ['Age', 'Condition No']
age_no = age_no.astype(int)

# %%
condition_by_age = pd.merge(age_yes, age_no, on='Age')
condition_by_age = pd.merge(condition_by_age, age_total, on='Age')

# %%
condition_by_age['% Yes'] = round(condition_by_age['Condition Yes'] / condition_by_age['Total'] * 100, 1)
condition_by_age['% No'] = round(condition_by_age['Condition No'] / condition_by_age['Total'] * 100, 1)
condition_by_age
# Out:
#     Age  Condition Yes  Condition No  Total  % Yes  % No
# 0    18              3             2      5   60.0  40.0
# 1    19              3             5      8   37.5  62.5
# 2    20              1             2      3   33.3  66.7
# 3    21              8             8     16   50.0  50.0
# 4    22             10             5     15   66.7  33.3
# 5    23             23            23     46   50.0  50.0
# 6    24             18            26     44   40.9  59.1
# 7    25             33            22     55   60.0  40.0
# 8    26             35            26     61   57.4  42.6
# 9    27             27            32     59   45.8  54.2
# 10   28             34            24     58   58.6  41.4
# 11   29             32            42     74   43.2  56.8
# 12   30             31            26     57   54.4  45.6
# 13   31             28            29     57   49.1  50.9
# 14   32             40            39     79   50.6  49.4
# ...

# %%
ay = plt.bar(condition_by_age['Age'], condition_by_age['% Yes'], color='c')
an = plt.bar(condition_by_age['Age'], condition_by_age['% No'], bottom=condition_by_age['% Yes'], color='lavender')
plt.ylabel('% Records')
plt.xlabel('Age (years)')
plt.title('MH Condition by Age')
plt.legend((ay,an),('Yes','No'))
plt.show()

# %%
# the previous chart doesn't show clear conclusions so I'll groups the ages by ranges using bins
condition_by_age['Age bins'] = pd.cut(condition_by_age['Age'], 5, labels=['18-26','27-34','35-43','44-49','56-60'])
condition_by_age
# Out:
#     Age  Condition Yes  Condition No  Total  % Yes  % No Age bins
# 0    18              3             2      5   60.0  40.0    18-26
# 1    19              3             5      8   37.5  62.5    18-26
# 2    20              1             2      3   33.3  66.7    18-26
# 3    21              8             8     16   50.0  50.0    18-26
# 4    22             10             5     15   66.7  33.3    18-26
# 5    23             23            23     46   50.0  50.0    18-26
# 6    24             18            26     44   40.9  59.1    18-26
# 7    25             33            22     55   60.0  40.0    18-26
# 8    26             35            26     61   57.4  42.6    18-26
# 9    27             27            32     59   45.8  54.2    27-34
# 10   28             34            24     58   58.6  41.4    27-34
# 11   29             32            42     74   43.2  56.8    27-34
# 12   30             31            26     57   54.4  45.6    27-34
# ...

# %%
condition_by_age_bins = condition_by_age.groupby('Age bins').mean()
condition_by_age_bins.reset_index(inplace=True)
condition_by_age_bins
# Out:
#   Age bins        Age  Condition Yes  Condition No      Total      % Yes  \
# 0    18-26  22.000000      14.888889     13.222222  28.111111  50.644444
# 1    27-34  30.500000      32.125000     31.375000  63.500000  50.812500
# 2    35-43  39.000000      17.666667     14.222222  31.888889  56.266667
# 3    44-49  46.500000       4.666667      3.000000   7.666667  57.700000
# 4    56-60  57.666667       2.000000      1.000000   3.000000  63.900000
#
#         % No
# 0  49.355556
# 1  49.187500
# 2  43.733333
# 3  42.300000
# 4  36.100000

# %%
ayb = plt.bar(condition_by_age_bins['Age bins'], condition_by_age_bins['% Yes'], color='c')
anb = plt.bar(condition_by_age_bins['Age bins'], condition_by_age_bins['% No'], bottom=condition_by_age_bins['% Yes'], color='lavender')
plt.ylabel('% Records')
plt.xlabel('Age (years)')
plt.title('MH Condition by Age')
plt.legend((ayb,anb),('Yes','No'))
plt.show()

# %% [markdown]
# Conclusion: from this chart we see an slightly increasing tendency of MH condition with age.

# %% [markdown]
# #### 3.3 MH condition by Gender
# I'll manipulate the data to get a table with the percentage of 'Yes' and 'No' for the MH Condition (using the treatment), by gender and weighted with the number of records per gender.

# %%
gender_total = data[['Gender','treatment']].groupby('Gender').count()
gender_total.reset_index(inplace=True)
gender_total.columns = ['Gender', 'Total']
gender_total
# Out:
#   Gender  Total
# 0    man    878
# 1  woman    237

# %%
gender_yes = data[['Gender','treatment']][data['treatment'] == 'Yes'].groupby('Gender').count()
gender_yes.reset_index(inplace=True)
gender_yes.columns = ['Gender', 'Condition Yes']
gender_yes
# Out:
#   Gender  Condition Yes
# 0    man            418
# 1  woman            166

# %%
gender_no = data[['Gender','treatment']][data['treatment'] == 'No'].groupby('Gender').count()
gender_no.reset_index(inplace=True)
gender_no.columns = ['Gender', 'Condition No']
gender_no
# Out:
#   Gender  Condition No
# 0    man           460
# 1  woman            71

# %%
condition_by_gender = pd.merge(gender_yes, gender_no, on='Gender')
condition_by_gender = pd.merge(condition_by_gender, gender_total, on='Gender')
condition_by_gender
# Out:
#   Gender  Condition Yes  Condition No  Total
# 0    man            418           460    878
# 1  woman            166            71    237

# %%
condition_by_gender['% Yes'] = round(condition_by_gender['Condition Yes'] / condition_by_gender['Total'] * 100, 1)
condition_by_gender['% No'] = round(condition_by_gender['Condition No'] / condition_by_gender['Total'] * 100, 1)
condition_by_gender
# Out:
#   Gender  Condition Yes  Condition No  Total  % Yes  % No
# 0    man            418           460    878   47.6  52.4
# 1  woman            166            71    237   70.0  30.0

# %%
gy = plt.bar(condition_by_gender['Gender'], condition_by_gender['% Yes'], color='c')
gn = plt.bar(condition_by_gender['Gender'], condition_by_gender['% No'], bottom=condition_by_gender['% Yes'], color='lavender')
plt.ylabel('% Records')
plt.title('MH Condition by Gender')
plt.legend((gy,gn),('Yes','No'))
plt.show()

# %% [markdown]
# Conclusion: from this chart we see that there are more woman with MH condition than man.
