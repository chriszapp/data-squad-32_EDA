# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('frequency.csv',index_col=[0])

# %%
data
# Out:
#     state  family_history  treatment  rate
# 0      IL             0.0        1.0   1.0
# 1      IN             0.0        0.0   0.0
# 2      TX             0.0        0.0   0.0
# 3      TN             1.0        0.0   2.0
# 4      MI             1.0        1.0   3.0
# ..    ...             ...        ...   ...
# 735    UT             1.0        0.0   2.0
# 736    IL             1.0        1.0   3.0
# 737    CA             1.0        1.0   3.0
# 738    NC             0.0        0.0   0.0
# 739    IL             1.0        1.0   3.0
#
# [740 rows x 4 columns]

# %%
data=data[['state','family_history','treatment']]
data=data.groupby(['state','family_history','treatment']).size().reset_index().rename(columns={0:'count'})
data.head(50)
# Out:
#    state  family_history  treatment  count
# 0     AL             0.0        0.0      1
# 1     AL             0.0        1.0      2
# 2     AL             1.0        1.0      5
# 3     AZ             0.0        0.0      1
# 4     AZ             0.0        1.0      3
# 5     AZ             1.0        1.0      3
# 6     CA             0.0        0.0     35
# 7     CA             0.0        1.0     35
# 8     CA             1.0        0.0     17
# 9     CA             1.0        1.0     51
# 10    CO             0.0        0.0      5
# 11    CO             0.0        1.0      2
# 12    CO             1.0        1.0      2
# 13    CT             0.0        0.0      1
# 14    CT             0.0        1.0      2
# 15    CT             1.0        0.0      1
# 16    DC             0.0        0.0      2
# 17    DC             1.0        0.0      1
# 18    DC             1.0        1.0      1
# 19    FL             0.0        0.0      7
# 20    FL             0.0        1.0      4
# ...

# %%
fam_treatment=data[(data['treatment']==1.0) & (data['family_history']==1.0)].reset_index(drop=True)
fam_treatment
# Out:
#    state  family_history  treatment  count
# 0     AL             1.0        1.0      5
# 1     AZ             1.0        1.0      3
# 2     CA             1.0        1.0     51
# 3     CO             1.0        1.0      2
# 4     DC             1.0        1.0      1
# 5     FL             1.0        1.0      4
# 6     GA             1.0        1.0      3
# 7     IA             1.0        1.0      1
# 8     ID             1.0        1.0      1
# 9     IL             1.0        1.0     13
# 10    IN             1.0        1.0     10
# 11    MA             1.0        1.0      3
# 12    MD             1.0        1.0      2
# 13    ME             1.0        1.0      1
# 14    MI             1.0        1.0      8
# 15    MN             1.0        1.0      8
# 16    MO             1.0        1.0      3
# 17    NC             1.0        1.0      5
# 18    NE             1.0        1.0      1
# 19    NH             1.0        1.0      2
# 20    NJ             1.0        1.0      2
# ...

# %%
fig, ax = plt.subplots(figsize=(20,10))

# Example data
people = fam_treatment['state']
y_pos=range(0,35)

ax.barh(y_pos,fam_treatment['count'], align='center',color='green')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Number of people')
ax.set_title('Number of people that did treatment and have family history')

for i, v in enumerate(fam_treatment['count']):
    ax.text(v+0.1, i + .25, str(v), color='red', fontweight='bold')

plt.show()
