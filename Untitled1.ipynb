# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds = pd.read_csv('survey.csv')
ds
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
ds[ds['work_interfere'].isnull()]
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 19    2014-08-27 11:35:08   36    Male          France   NaN           Yes
# 26    2014-08-27 11:37:23   33    male   United States    TN            No
# 37    2014-08-27 11:41:50   38    Male        Portugal   NaN            No
# 38    2014-08-27 11:42:08   50       M   United States    IN            No
# 41    2014-08-27 11:42:31   35    Male   United States    MI            No
# ...                   ...  ...     ...             ...   ...           ...
# 1226  2015-02-21 17:19:18   39    Male     Netherlands   NaN            No
# 1229  2015-02-22 02:40:32   39    Male          Greece   NaN            No
# 1244  2015-05-05 15:16:25   32  female  United Kingdom   NaN            No
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
ds[(ds['work_interfere'].isnull()) & (ds['treatment']=='Yes')]
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 500   2014-08-27 16:29:23   38  female   United States    AZ            No
# 937   2014-08-28 22:23:47   33    Male     Netherlands   NaN            No
# 1202  2015-02-21 05:34:27   31    Male          Brazil   NaN           Yes
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
#
#      family_history treatment work_interfere no_employees  ...          leave  \
# 500              No       Yes            NaN       26-100  ...     Don't know
# 937             Yes       Yes            NaN         6-25  ...     Don't know
# 1202             No       Yes            NaN          1-5  ...     Don't know
# 1254             No       Yes            NaN       26-100  ...  Somewhat easy
#
#      mental_health_consequence phys_health_consequence     coworkers  \
# 500                      Maybe                   Maybe            No
# ...

# %%
ds_not_ill=ds[(ds['treatment']=='No') & ((ds['work_interfere']=='Never') | (ds['work_interfere'].isnull()))]

# %%
ds['Ill']=[0 if ((ds['treatment'][i]=='No') & ((ds['work_interfere'][i]!='Often') & (ds['work_interfere'][i]!='Rarely') & (ds['work_interfere'][i]!='Sometimes'))) else 1 for i in range(len(ds))]

# %%
ds_ill=ds[ds['Ill']==1]

# %%
i_ni=ds.pivot_table(index=['Ill'], aggfunc='count')['Age']

# %%
plt.pie(i_ni, labels=['Not ill','Ill'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x11cad6b50>,
# ...
#  [Text(0.49363363595019694, 0.9830187350496371, 'Not ill'),
#   Text(-0.4936335439133382, -0.9830187812669494, 'Ill')],
#  [Text(0.2692547105182892, 0.536192037299802, '35.2%'),
#   Text(-0.26925466031636625, -0.5361920625092451, '64.8%')])

# %%
set(ds['work_interfere'])
# Out:
# {'Never', 'Often', 'Rarely', 'Sometimes', nan}

# %%
ds[(ds['Country']=='United States')]
# Out:
#                 Timestamp  Age  Gender        Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female  United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M  United States    IN           NaN
# 4     2014-08-27 11:30:22   31    Male  United States    TX           NaN
# 5     2014-08-27 11:31:22   33    Male  United States    TN           NaN
# 6     2014-08-27 11:31:50   35  Female  United States    MI           NaN
# ...                   ...  ...     ...            ...   ...           ...
# 1253  2015-08-25 19:59:38   36    Male  United States    UT            No
# 1255  2015-09-26 01:07:35   32    Male  United States    IL            No
# 1256  2015-11-07 12:36:58   34    male  United States    CA            No
# 1257  2015-11-30 21:25:06   46       f  United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male  United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
ds[~(ds['comments'].isnull())]
# Out:
#                 Timestamp  Age  \
# 13    2014-08-27 11:33:26   36
# 15    2014-08-27 11:34:00   29
# 16    2014-08-27 11:34:20   23
# 24    2014-08-27 11:36:48   33
# 25    2014-08-27 11:37:08   35
# ...                   ...  ...
# 1223  2015-02-21 11:55:46   23
# 1232  2015-02-24 09:00:56   25
# 1234  2015-02-24 09:15:13   24
# 1245  2015-05-06 10:14:50   22
# 1249  2015-07-22 18:57:54   30
#
#                                               Gender         Country state  \
# 13                                              Male   United States    CT
# 15                                            female   United States    IL
# 16                                              Male  United Kingdom   NaN
# 24                                              male   United States    CA
# 25                                              male   United States    TN
# ...                                              ...             ...   ...
# ...

# %%
ds_tech=ds.pivot_table(index=['tech_company'], aggfunc='count')['Age']
ds_tech
# Out:
# tech_company
# No      228
# Yes    1031
# Name: Age, dtype: int64

# %%
plt.pie(ds_tech, labels=['Not tech','Tech'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x11cb61310>,
# ...
#  [Text(0.9267255716378282, 0.5926041806067022, 'Not tech'),
#   Text(-0.9267256271214317, -0.5926040938403895, 'Tech')],
#  [Text(0.5054866754388153, 0.323238643967292, '18.1%'),
#   Text(-0.505486705702599, -0.3232385966402124, '81.9%')])

# %%
ds_tech_ill=ds_ill.pivot_table(index=['tech_company'], aggfunc='count')['Age']
ds_tech_ill
# Out:
# tech_company
# No     152
# Yes    664
# Name: Age, dtype: int64

# %%
plt.pie(ds_tech_ill, labels=['Not tech','Tech'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x11cbae990>,
# ...
#  [Text(0.9169626164928313, 0.6076014811985081, 'Not tech'),
#   Text(-0.9169626449367084, -0.6076014382723893, 'Tech')],
#  [Text(0.5001614271779079, 0.33141898974464074, '18.6%'),
#   Text(-0.50016144269275, -0.33141896633039414, '81.4%')])

# %%
ds_self_ill=ds_ill.pivot_table(index=['self_employed'], aggfunc='count')['Age']
ds_self_ill
# Out:
# self_employed
# No     701
# Yes    103
# Name: Age, dtype: int64

# %%
plt.pie(ds_self_ill, labels=['Not self-employed','Self-employed'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x11cd81b50>,
# ...
#  [Text(-1.0121069352870924, 0.4308590854836066, 'Not self-employed'),
#   Text(1.0121069352870922, -0.4308590854836067, 'Self-employed')],
#  [Text(-0.552058328338414, 0.23501404662742173, '87.2%'),
#   Text(0.5520583283384138, -0.2350140466274218, '12.8%')])

# %%
ds_ill_inter=ds_ill.pivot_table(index=['work_interfere'], aggfunc='count')['Age']
ds_ill_inter
# Out:
# work_interfere
# Never         30
# Often        144
# Rarely       173
# Sometimes    465
# Name: Age, dtype: int64

# %%
plt.pie(ds_ill_inter, labels=['Never','Often','Rarely','Sometimes'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x11ce35810>,
# ...
#  [Text(1.0925987469036456, 0.12738908220324008, 'Never'),
#   Text(0.7748023174671202, 0.7808209582532861, 'Often'),
#   Text(-0.4734341050527399, 0.9929049038920652, 'Rarely'),
#   Text(-0.24892045091240783, -1.0714656359947172, 'Sometimes')],
#  [Text(0.5959629528565339, 0.06948495392904004, '3.7%'),
#   Text(0.42261944589115646, 0.4259023408654287, '17.7%'),
#   Text(-0.2582367845742218, 0.5415844930320355, '21.3%'),
#   Text(-0.1357747914067679, -0.5844358014516638, '57.3%')])

# %%
ds_cowk=ds.pivot_table(index=['coworkers'], aggfunc='count')['Age']
ds_cowk
# Out:
# coworkers
# No              260
# Some of them    774
# Yes             225
# Name: Age, dtype: int64

# %%
plt.pie(ds_cowk, labels=['No','Some of them','Yes'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x11cecd1d0>,
# ...
#  [Text(0.8765036472792588, 0.6646362586454014, 'No'),
#   Text(-1.0958075189491134, -0.09594728456078676, 'Some of them'),
#   Text(0.9311357557387275, -0.5856502406597891, 'Yes')],
#  [Text(0.47809289851595926, 0.36252886835203707, '20.7%'),
#   Text(-0.5977131921540618, -0.052334882487701864, '61.5%'),
#   Text(0.5078922304029422, -0.3194455858144304, '17.9%')])

# %%
ds_super=ds.pivot_table(index=['supervisor'], aggfunc='count')['Age']
ds_super
# Out:
# supervisor
# No              393
# Some of them    350
# Yes             516
# Name: Age, dtype: int64

# %%
plt.pie(ds_super, labels=['No','Some of them','Yes'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x11d046790>,
# ...
#  [Text(0.6121253678843057, 0.9139488683687417, 'No'),
#   Text(-1.04859455304678, 0.33233937973196037, 'Some of them'),
#   Text(0.3073910241134953, -1.0561774274687263, 'Yes')],
#  [Text(0.3338865643005303, 0.49851756456476815, '31.2%'),
#   Text(-0.5719606652982435, 0.181276025308342, '27.8%'),
#   Text(0.16766783133463375, -0.5760967786193052, '41.0%')])

# %%
ds_mental_int=ds.pivot_table(index=['mental_health_interview'], aggfunc='count')['Age']
ds_mental_int
# Out:
# mental_health_interview
# Maybe     207
# No       1008
# Yes        44
# Name: Age, dtype: int64

# %%
plt.pie(ds_mental_int, labels=['Maybe','No','Yes'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x11d0fc2d0>,
# ...
#  [Text(0.9564926151513479, 0.5432512099949117, 'Maybe'),
#   Text(-1.0102590711556036, -0.4351742284968367, 'No'),
#   Text(1.0933765980267969, -0.12053055582444104, 'Yes')],
#  [Text(0.5217232446280079, 0.29631884181540635, '16.4%'),
#   Text(-0.551050402448511, -0.23736776099827453, '80.1%'),
#   Text(0.5963872352873436, -0.0657439395406042, '3.5%')])

# %%
ds_phys_int=ds.pivot_table(index=['phys_health_interview'], aggfunc='count')['Age']
ds_phys_int
# Out:
# phys_health_interview
# Maybe    557
# No       500
# Yes      202
# Name: Age, dtype: int64

# %%
plt.pie(ds_phys_int, labels=['Maybe','No','Yes'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x11d19f710>,
# ...
#  [Text(0.1979170961657872, 1.0820484384006581, 'Maybe'),
#   Text(-0.6959079635211003, -0.8518873788875588, 'No'),
#   Text(0.9631959012338688, -0.5312754990080717, 'Yes')],
#  [Text(0.107954779726793, 0.5902082391276317, '44.2%'),
#   Text(-0.37958616192060013, -0.4646658430295775, '39.7%'),
#   Text(0.5253795824912011, -0.2897866358225845, '16.0%')])

# %%
print(set(ds_tech['no_employees']))
print(set(ds_tech['Country']))
# Out:
# {'1-5', '26-100', 'More than 1000', '6-25', '500-1000', '100-500'}
# {'United States', 'Australia', 'Belgium', 'Bosnia and Herzegovina', 'Japan', 'Latvia', 'Nigeria', 'China', 'Canada', 'Slovenia', 'New Zealand', 'Ireland', 'Denmark', 'Singapore', 'Greece', 'Hungary', 'Czech Republic', 'Moldova', 'Switzerland', 'Russia', 'Uruguay', 'Brazil', 'Thailand', 'Bahamas, The', 'Israel', 'Bulgaria', 'Croatia', 'France', 'Costa Rica', 'Colombia', 'Spain', 'United Kingdom', 'Mexico', 'South Africa', 'Zimbabwe', 'Sweden', 'Philippines', 'Finland', 'Poland', 'Norway', 'Germany', 'Netherlands', 'Italy', 'India', 'Portugal', 'Austria'}

# %%
ds_tech_notill=ds_tech[(ds_tech['treatment']=='No') & ((ds_tech['work_interfere']=='Never') | (ds_tech['work_interfere'].isnull()))]

# %%
len(ds_tech_notill['Age'])/len(ds_tech['Age'])
# Out:
# 0.3559650824442289
