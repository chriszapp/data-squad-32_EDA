# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('frequency.csv',index_col=[0])

# %%
data
# Out:
#     state  family_history  treatment  rate
# 0      IL             0.0        1.0   1.0
# 1      IN             0.0        0.0   0.0
# 2      TX             0.0        0.0   0.0
# 3      TN             1.0        0.0   2.0
# 4      MI             1.0        1.0   3.0
# ..    ...             ...        ...   ...
# 735    UT             1.0        0.0   2.0
# 736    IL             1.0        1.0   3.0
# 737    CA             1.0        1.0   3.0
# 738    NC             0.0        0.0   0.0
# 739    IL             1.0        1.0   3.0
#
# [740 rows x 4 columns]

# %%
data=data[['state','family_history','treatment']]
data=data.groupby(['state','family_history','treatment']).size().reset_index().rename(columns={0:'count'})
data.head(50)
# Out:
#    state  family_history  treatment  count
# 0     AL             0.0        0.0      1
# 1     AL             0.0        1.0      2
# 2     AL             1.0        1.0      5
# 3     AZ             0.0        0.0      1
# 4     AZ             0.0        1.0      3
# 5     AZ             1.0        1.0      3
# 6     CA             0.0        0.0     35
# 7     CA             0.0        1.0     35
# 8     CA             1.0        0.0     17
# 9     CA             1.0        1.0     51
# 10    CO             0.0        0.0      5
# 11    CO             0.0        1.0      2
# 12    CO             1.0        1.0      2
# 13    CT             0.0        0.0      1
# 14    CT             0.0        1.0      2
# 15    CT             1.0        0.0      1
# 16    DC             0.0        0.0      2
# 17    DC             1.0        0.0      1
# 18    DC             1.0        1.0      1
# 19    FL             0.0        0.0      7
# 20    FL             0.0        1.0      4
# 21    FL             1.0        1.0      4
# 22    GA             0.0        0.0      3
# 23    GA             0.0        1.0      3
# 24    GA             1.0        0.0      3
# 25    GA             1.0        1.0      3
# 26    IA             0.0        0.0      1
# 27    IA             0.0        1.0      2
# 28    IA             1.0        1.0      1
# 29    ID             1.0        1.0      1
# 30    IL             0.0        0.0      8
# 31    IL             0.0        1.0      6
# 32    IL             1.0        0.0      1
# 33    IL             1.0        1.0     13
# 34    IN             0.0        0.0     12
# 35    IN             0.0        1.0      3
# 36    IN             1.0        0.0      2
# 37    IN             1.0        1.0     10
# 38    KS             0.0        0.0      3
# 39    KY             0.0        0.0      3
# 40    KY             0.0        1.0      1
# 41    KY             1.0        0.0      1
# 42    LA             0.0        1.0      1
# 43    MA             0.0        0.0      8
# 44    MA             0.0        1.0      7
# 45    MA             1.0        0.0      2
# 46    MA             1.0        1.0      3
# 47    MD             0.0        0.0      4
# 48    MD             1.0        0.0      1
# 49    MD             1.0        1.0      2

# %%
fam_treatment=data[(data['treatment']==1.0) & (data['family_history']==1.0)].reset_index(drop=True)
fam_treatment=fam_treatment.sort_values(by='count',ascending=False)
fam_treatment
# Out:
#    state  family_history  treatment  count
# 2     CA             1.0        1.0     51
# 32    WA             1.0        1.0     29
# 21    NY             1.0        1.0     18
# 28    TN             1.0        1.0     15
# 9     IL             1.0        1.0     13
# 25    PA             1.0        1.0     11
# 24    OR             1.0        1.0     11
# 10    IN             1.0        1.0     10
# 29    TX             1.0        1.0      9
# 14    MI             1.0        1.0      8
# 22    OH             1.0        1.0      8
# 15    MN             1.0        1.0      8
# 33    WI             1.0        1.0      6
# 0     AL             1.0        1.0      5
# 17    NC             1.0        1.0      5
# 5     FL             1.0        1.0      4
# 6     GA             1.0        1.0      3
# 1     AZ             1.0        1.0      3
# 11    MA             1.0        1.0      3
# 31    VA             1.0        1.0      3
# 16    MO             1.0        1.0      3
# 30    UT             1.0        1.0      3
# 3     CO             1.0        1.0      2
# 19    NH             1.0        1.0      2
# 20    NJ             1.0        1.0      2
# 12    MD             1.0        1.0      2
# 13    ME             1.0        1.0      1
# 4     DC             1.0        1.0      1
# 7     IA             1.0        1.0      1
# 27    SD             1.0        1.0      1
# 26    SC             1.0        1.0      1
# 8     ID             1.0        1.0      1
# 23    OK             1.0        1.0      1
# 18    NE             1.0        1.0      1
# 34    WY             1.0        1.0      1

# %%
data
# Out:
#     state  family_history  treatment  count
# 0      AL             0.0        0.0      1
# 1      AL             0.0        1.0      2
# 2      AL             1.0        1.0      5
# 3      AZ             0.0        0.0      1
# 4      AZ             0.0        1.0      3
# ..    ...             ...        ...    ...
# 128    WI             1.0        0.0      1
# 129    WI             1.0        1.0      6
# 130    WV             0.0        0.0      1
# 131    WY             0.0        0.0      1
# 132    WY             1.0        1.0      1
#
# [133 rows x 4 columns]

# %%
data
# Out:
#     state  family_history  treatment  count
# 0      AL             0.0        0.0      1
# 1      AL             0.0        1.0      2
# 2      AL             1.0        1.0      5
# 3      AZ             0.0        0.0      1
# 4      AZ             0.0        1.0      3
# ..    ...             ...        ...    ...
# 128    WI             1.0        0.0      1
# 129    WI             1.0        1.0      6
# 130    WV             0.0        0.0      1
# 131    WY             0.0        0.0      1
# 132    WY             1.0        1.0      1
#
# [133 rows x 4 columns]

# %%
df=pd.read_csv('rate',index_col=[0])
df
# Out:
#    state   rate
# 0     AL   17.0
# 1     AZ   12.0
# 2     CA  222.0
# 3     CO    8.0
# 4     CT    4.0
# 5     DC    5.0
# 6     FL   16.0
# 7     GA   18.0
# 8     IA    5.0
# 9     ID    3.0
# 10    IL   47.0
# 11    IN   37.0
# 12    KS    0.0
# 13    KY    3.0
# 14    LA    1.0
# 15    MA   20.0
# 16    MD    8.0
# 17    ME    3.0
# 18    MI   28.0
# 19    MN   30.0
# 20    MO   18.0
# 21    MS    1.0
# 22    NC   21.0
# 23    NE    3.0
# 24    NH    6.0
# 25    NJ    7.0
# 26    NM    0.0
# 27    NV    2.0
# 28    NY   74.0
# 29    OH   38.0
# 30    OK    6.0
# 31    OR   45.0
# 32    PA   46.0
# 33    RI    0.0
# 34    SC    4.0
# 35    SD    3.0
# 36    TN   72.0
# 37    TX   51.0
# 38    UT   14.0
# 39    VA   16.0
# 40    VT    2.0
# 41    WA  111.0
# 42    WI   23.0
# 43    WV    0.0
# 44    WY    3.0

# %%
df=df.sort_values(by='rate',ascending=False)
df.reset_index(inplace=True)

# %%
fig1, ax = plt.subplots(figsize=(20,10))

# Example data
people = df['state']
y_pos=range(0,43)

ax.barh(y_pos,df['rate'], align='center',color='dodgerblue')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Number of people')
ax.set_title('Number of people that did treatment and have family history')

for i, v in enumerate(df['rate']):
    ax.text(v+0.1, i + .25, str(v), color='darkorange', fontweight='bold')

#plt.savefig('patientsandfamily.png')
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-c42dcd408d90> in <module>
#       5 y_pos=range(0,43)
#       6
# ----> 7 ax.barh(y_pos,df['rate'], align='center',color='dodgerblue')
#       8 ax.set_yticks(y_pos)
#       9 ax.set_yticklabels(people)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2594         kwargs.setdefault('orientation', 'horizontal')
#    2595         patches = self.bar(x=left, height=height, width=width, bottom=y,
# -> 2596                            align=align, **kwargs)
#    2597         return patches
#    2598
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2372         x, height, width, y, linewidth = np.broadcast_arrays(
#    2373             # Make args iterable too.
# -> 2374             np.atleast_1d(x), height, width, y, linewidth)
#    2375
#    2376         # Now that units have been converted, set the tick locations.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     262     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     263
# --> 264     shape = _broadcast_shape(*args)
#     265
#     266     if all(array.shape == shape for array in args):
#
# ~\Anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     189     # use the old-iterator because np.nditer does not handle size 0 arrays
#     190     # consistently
# --> 191     b = np.broadcast(*args[:32])
#     192     # unfortunately, it cannot handle 32 or more arguments directly
#     193     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
