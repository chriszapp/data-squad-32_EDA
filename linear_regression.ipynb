# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
data=pd.read_csv('linear_regression.csv',index_col=[0])

# %%
data
# Out:
#    state   rate  valuation
# 0     WY    3.0      -1.75
# 1     WV    0.0       0.00
# 2     WI   23.0      40.00
# 3     WA  111.0     182.75
# 4     VT    2.0      -4.00
# 5     VA   16.0      18.00
# 6     UT   14.0      18.50
# 7     TX   51.0      10.50
# 8     TN   72.0      28.25
# 9     SD    3.0       8.50
# 10    SC    4.0       7.75
# 11    RI    0.0      -3.00
# 12    PA   46.0      48.50
# 13    OR   45.0      34.00
# 14    OK    6.0      -6.25
# 15    OH   38.0      21.75
# 16    NY   74.0      98.50
# 17    NV    2.0       0.25
# 18    NM    0.0      -6.75
# 19    NJ    7.0      16.50
# 20    NH    6.0       7.75
# 21    NE    3.0       2.00
# 22    NC   21.0      24.25
# 23    MS    1.0       0.00
# 24    MO   18.0     -19.00
# 25    MN   30.0      12.75
# 26    MI   28.0       4.75
# 27    ME    3.0       0.00
# 28    MD    8.0      -0.50
# 29    MA   20.0      44.50
# 30    LA    1.0       3.00
# 31    KY    3.0       6.50
# 32    KS    0.0       0.75
# ...

# %%
Y = data['valuation'].values.reshape(-1,1) 
X = data['rate'].values.reshape(-1,1)
lm = LinearRegression() 
model = lm.fit(X,Y)
predictions = lm.predict(X)

fig, ax = plt.subplots(figsize=(9,5))
ax.scatter(X, Y,  color='green')
ax.plot(X, predictions, color='blue', linewidth=1)

ax.set(xlabel='number of patients ', ylabel='infrastructure',
       title='Number of patients vs infrastructure')
ax.grid()

fig.savefig("linear_regression.png")
plt.show()
